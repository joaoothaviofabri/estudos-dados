# %%
import pandas as pd
import numpy as np

df = pd.read_csv("automoveis_dados.csv")

# %%
display(df)
# Out:
#      nivel_risco perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                   ?  alfa-romero         gasolina    padrao
# 1              3                   ?  alfa-romero         gasolina    padrao
# 2              1                   ?  alfa-romero         gasolina    padrao
# 3              2                 164         audi         gasolina    padrao
# 4              2                 164         audi         gasolina    padrao
# ..           ...                 ...          ...              ...       ...
# 200           -1                  95        volvo         gasolina    padrao
# 201           -1                  95        volvo         gasolina     turbo
# 202           -1                  95        volvo         gasolina    padrao
# 203           -1                  95        volvo           diesel     turbo
# 204           -1                  95        volvo         gasolina     turbo
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nivel_risco          205 non-null    int64
#  1   perdas_normalizadas  205 non-null    object
#  2   marca                205 non-null    object
#  3   tipo_combustivel     205 non-null    object
#  4   aspiracao            205 non-null    object
#  5   numero_portas        205 non-null    object
#  6   tipo_carroceria      205 non-null    object
#  7   tracao               205 non-null    object
#  8   local_motor          205 non-null    object
#  9   distancia_eixos      205 non-null    float64
#  10  comprimento          205 non-null    float64
#  11  largura              205 non-null    float64
#  12  altura               205 non-null    float64
#  13  peso                 205 non-null    int64
#  14  tipo_motor           205 non-null    object
# ...

# %%
df_tratamento = df

# %%
df_tratamento
# Out:
#      nivel_risco perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                   ?  alfa-romero         gasolina    padrao
# 1              3                   ?  alfa-romero         gasolina    padrao
# 2              1                   ?  alfa-romero         gasolina    padrao
# 3              2                 164         audi         gasolina    padrao
# 4              2                 164         audi         gasolina    padrao
# ..           ...                 ...          ...              ...       ...
# 200           -1                  95        volvo         gasolina    padrao
# 201           -1                  95        volvo         gasolina     turbo
# 202           -1                  95        volvo         gasolina    padrao
# 203           -1                  95        volvo           diesel     turbo
# 204           -1                  95        volvo         gasolina     turbo
#
# ...

# %%
df_tratamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nivel_risco          205 non-null    int64
#  1   perdas_normalizadas  205 non-null    object
#  2   marca                205 non-null    object
#  3   tipo_combustivel     205 non-null    object
#  4   aspiracao            205 non-null    object
#  5   numero_portas        205 non-null    object
#  6   tipo_carroceria      205 non-null    object
#  7   tracao               205 non-null    object
#  8   local_motor          205 non-null    object
#  9   distancia_eixos      205 non-null    float64
#  10  comprimento          205 non-null    float64
#  11  largura              205 non-null    float64
#  12  altura               205 non-null    float64
#  13  peso                 205 non-null    int64
#  14  tipo_motor           205 non-null    object
# ...

# %%
df_tratamento["perdas_normalizadas"] = df_tratamento["perdas_normalizadas"].replace("?", np.nan)
df_tratamento
# Out:
#      nivel_risco perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                 NaN  alfa-romero         gasolina    padrao
# 1              3                 NaN  alfa-romero         gasolina    padrao
# 2              1                 NaN  alfa-romero         gasolina    padrao
# 3              2                 164         audi         gasolina    padrao
# 4              2                 164         audi         gasolina    padrao
# ..           ...                 ...          ...              ...       ...
# 200           -1                  95        volvo         gasolina    padrao
# 201           -1                  95        volvo         gasolina     turbo
# 202           -1                  95        volvo         gasolina    padrao
# 203           -1                  95        volvo           diesel     turbo
# 204           -1                  95        volvo         gasolina     turbo
#
# ...

# %%
df_tratamento["perdas_normalizadas"] = pd.to_numeric(df_tratamento["perdas_normalizadas"])
df_tratamento
# Out:
#      nivel_risco  perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                  NaN  alfa-romero         gasolina    padrao
# 1              3                  NaN  alfa-romero         gasolina    padrao
# 2              1                  NaN  alfa-romero         gasolina    padrao
# 3              2                164.0         audi         gasolina    padrao
# 4              2                164.0         audi         gasolina    padrao
# ..           ...                  ...          ...              ...       ...
# 200           -1                 95.0        volvo         gasolina    padrao
# 201           -1                 95.0        volvo         gasolina     turbo
# 202           -1                 95.0        volvo         gasolina    padrao
# 203           -1                 95.0        volvo           diesel     turbo
# 204           -1                 95.0        volvo         gasolina     turbo
#
# ...

# %%
df_tratamento["perdas_normalizadas"].median()
# Out:
# np.float64(115.0)

# %%
df_tratamento["perdas_normalizadas"] = df_tratamento["perdas_normalizadas"].fillna(df_tratamento["perdas_normalizadas"].median())
df_tratamento
# Out:
#      nivel_risco  perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                115.0  alfa-romero         gasolina    padrao
# 1              3                115.0  alfa-romero         gasolina    padrao
# 2              1                115.0  alfa-romero         gasolina    padrao
# 3              2                164.0         audi         gasolina    padrao
# 4              2                164.0         audi         gasolina    padrao
# ..           ...                  ...          ...              ...       ...
# 200           -1                 95.0        volvo         gasolina    padrao
# 201           -1                 95.0        volvo         gasolina     turbo
# 202           -1                 95.0        volvo         gasolina    padrao
# 203           -1                 95.0        volvo           diesel     turbo
# 204           -1                 95.0        volvo         gasolina     turbo
#
# ...

# %%
df_tratamento["preco"] = df_tratamento["preco"].replace("?", np.nan)
df_tratamento["preco"] = pd.to_numeric(df_tratamento["preco"])

# %%
df_tratamento["potencia"] = df_tratamento["potencia"].replace("?", np.nan)
df_tratamento["potencia"] = pd.to_numeric(df_tratamento["potencia"])
df_tratamento["potencia"] = df_tratamento["potencia"].fillna(df_tratamento["potencia"].median())

# %%
df_tratamento["numero_portas"] = df_tratamento["numero_portas"].replace("?", np.nan)
df_tratamento["numero_portas"] = df_tratamento["numero_portas"].fillna("quatro")

# %%
df_tratamento["diametro_cilindro"] = df_tratamento["diametro_cilindro"].replace("?", np.nan)
df_tratamento["diametro_cilindro"] = pd.to_numeric(df_tratamento["diametro_cilindro"])
df_tratamento["diametro_cilindro"] = df_tratamento["diametro_cilindro"].fillna(df_tratamento["diametro_cilindro"].median())

# %%
df_tratamento["curso_pistao"] = df_tratamento["curso_pistao"].replace("?", np.nan)
df_tratamento["curso_pistao"] = pd.to_numeric(df_tratamento["curso_pistao"])
df_tratamento["curso_pistao"] = df_tratamento["curso_pistao"].fillna(df_tratamento["diametro_cilindro"].median())

# %%
df_tratamento["rpm_maximo"] = df_tratamento["rpm_maximo"].replace("?", np.nan)
df_tratamento["rpm_maximo"] = pd.to_numeric(df_tratamento["rpm_maximo"])
df_tratamento["rpm_maximo"] = df_tratamento["rpm_maximo"].fillna(df_tratamento["rpm_maximo"].median())

# %%
df_tratamento.to_csv("concessionaria_carros.csv")

# %%
df_tratamento['duas_portas'] = (df_tratamento['numero_portas'] == 'duas').map({True: 'Sim', False: 'Não'})
df_tratamento
# Out:
#      nivel_risco  perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                115.0  alfa-romero         gasolina    padrao
# 1              3                115.0  alfa-romero         gasolina    padrao
# 2              1                115.0  alfa-romero         gasolina    padrao
# 3              2                164.0         audi         gasolina    padrao
# 4              2                164.0         audi         gasolina    padrao
# ..           ...                  ...          ...              ...       ...
# 200           -1                 95.0        volvo         gasolina    padrao
# 201           -1                 95.0        volvo         gasolina     turbo
# 202           -1                 95.0        volvo         gasolina    padrao
# 203           -1                 95.0        volvo           diesel     turbo
# 204           -1                 95.0        volvo         gasolina     turbo
#
# ...

# %%
df_tratamento['quatro_portas'] = (df_tratamento['numero_portas'] == 'quatro').map({True: 'Sim', False: 'Não'})
df_tratamento
# Out:
#      nivel_risco  perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                115.0  alfa-romero         gasolina    padrao
# 1              3                115.0  alfa-romero         gasolina    padrao
# 2              1                115.0  alfa-romero         gasolina    padrao
# 3              2                164.0         audi         gasolina    padrao
# 4              2                164.0         audi         gasolina    padrao
# ..           ...                  ...          ...              ...       ...
# 200           -1                 95.0        volvo         gasolina    padrao
# 201           -1                 95.0        volvo         gasolina     turbo
# 202           -1                 95.0        volvo         gasolina    padrao
# 203           -1                 95.0        volvo           diesel     turbo
# 204           -1                 95.0        volvo         gasolina     turbo
#
# ...

# %%
df_infos = df_tratamento
df_infos
# Out:
#      nivel_risco  perdas_normalizadas        marca tipo_combustivel aspiracao  \
# 0              3                115.0  alfa-romero         gasolina    padrao
# 1              3                115.0  alfa-romero         gasolina    padrao
# 2              1                115.0  alfa-romero         gasolina    padrao
# 3              2                164.0         audi         gasolina    padrao
# 4              2                164.0         audi         gasolina    padrao
# ..           ...                  ...          ...              ...       ...
# 200           -1                 95.0        volvo         gasolina    padrao
# 201           -1                 95.0        volvo         gasolina     turbo
# 202           -1                 95.0        volvo         gasolina    padrao
# 203           -1                 95.0        volvo           diesel     turbo
# 204           -1                 95.0        volvo         gasolina     turbo
#
# ...

# %%
df_infos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nivel_risco          205 non-null    int64
#  1   perdas_normalizadas  205 non-null    float64
#  2   marca                205 non-null    object
#  3   tipo_combustivel     205 non-null    object
#  4   aspiracao            205 non-null    object
#  5   numero_portas        205 non-null    object
#  6   tipo_carroceria      205 non-null    object
#  7   tracao               205 non-null    object
#  8   local_motor          205 non-null    object
#  9   distancia_eixos      205 non-null    float64
#  10  comprimento          205 non-null    float64
#  11  largura              205 non-null    float64
#  12  altura               205 non-null    float64
#  13  peso                 205 non-null    int64
#  14  tipo_motor           205 non-null    object
# ...

# %%
df_infos.drop(['nivel_risco', 'perdas_normalizadas', 'marca', 'numero_portas', 'distancia_eixos', 'comprimento', 'largura', 'altura', 'peso', 'tipo_motor', 'numero_cilindros', 'tamanho_motor', 'diametro_cilindro', 'curso_pistao', 'taxa_compressao', 'potencia', 'rpm_maximo', 'consumo_cidade_mpg', 'consumo_estrada_mpg'], axis=1)
# Out:
#     tipo_combustivel aspiracao tipo_carroceria             tracao local_motor  \
# 0           gasolina    padrao     conversivel           traseira     frontal
# 1           gasolina    padrao     conversivel           traseira     frontal
# 2           gasolina    padrao       hatchback           traseira     frontal
# 3           gasolina    padrao           sedan          dianteira     frontal
# 4           gasolina    padrao           sedan  quatro_por_quatro     frontal
# ..               ...       ...             ...                ...         ...
# 200         gasolina    padrao           sedan           traseira     frontal
# 201         gasolina     turbo           sedan           traseira     frontal
# 202         gasolina    padrao           sedan           traseira     frontal
# 203           diesel     turbo           sedan           traseira     frontal
# 204         gasolina     turbo           sedan           traseira     frontal
#
# ...
